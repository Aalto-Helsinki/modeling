# %% [markdown]
# <img height="80%C" width="80%" src="http://i.imgur.com/BdWlYUy.jpg">

# %%
# %matplotlib inline
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt

# %% [markdown]
# ## Reactions

# %% [markdown]
# $$\frac{d[Acetoacetyl-CoA]}{dt} =  k_{AtoB}[Acetyl-CoA]^2 - k_{Hbd}[Acetoacetyl-CoA][NADPH]  $$

# %% [markdown]
# $$\frac{d[3-hydroxybutyryl-CoA]}{dt} =  k_{Hbd}[Acetoacetyl-CoA][NADPH] - k_{Crt}[3-hydroxybutyryl-CoA][H_2O]  $$

# %% [markdown]
# $$\frac{d[Crotonyl-CoA]}{dt} =  k_{Crt}[3-hydroxybutyryl-CoA][H_2O] - k_{Ter}[Crotonyl-CoA][NADH]  $$

# %% [markdown]
# $$\frac{d[Butyryl-CoA]}{dt} =  k_{Ter}[Crotonyl-CoA][NADH] - k_{YciA}[Butyryl-CoA][H_2O]  $$

# %% [markdown]
# $$\frac{d[Butyric-acid]}{dt} =  k_{YciA}[Butyryl-CoA][H_2O] - k_{CAR}[Butyric acid][NADPH][H_2O][ATP] $$

# %% [markdown]
# $$\frac{d[Butyraldehyde]}{dt} = k_{CAR}[Butyric acid][NADPH][H_2O][ATP] - k_{ADO}[Butyraldehyde][NADPH]^2[H_+]^2[O_2] $$

# %% [markdown]
# $$\frac{d[Propane]}{dt} = k_{ADO}[Butyraldehyde][NADPH]^2[H+]^2[O2] $$

# %% [markdown]
# $$\frac {d[CAR_{holo}]}{dt} = k_{sfp}[CAR_{apo}][CoA]-k_{CAR}[butyricacid][NADPH][H_2O][ATP] $$

# %% [markdown]
# $$\frac{d[PetF_{red}]}{dt} = k_{Fpr}[NADPH]-k_{ADO}[Butyraldehyde][NADPH]^2[H+]^2[O2] $$

# %% [markdown]
# $$ \frac {d[H_2O_2]}{dt} = k_{Fpr}[NADPH]-k_{KatE}[H_2O_2] $$

# %% [markdown]
# $$\frac{d[NADPH]}{dt} = -k_{Hbd}[acetoacetyl-CoA][NADPH]-k_{CAR}[butyricacid][ATP]-k_{ADO}[butyraldehyde][NADPH]^2[H+]^2[O_2] $$

# %% [markdown]
# $$ \frac{d[NADH]}{dt} = -k_{ter}[crotonyl-CoA][NADH] $$

# %%
# Define constants
#I have assumed we'll get infinite apo-enzyme to get the calculation for working version & constant CoA
K_AtoB = 0.47
K_Hbd = 0.05
K_Crt = 0.03
K_Ter = 0.0052
K_YciA = 6.7
K_CAR = 0.362
K_ADO = 0.5
K_Sfp = 0.00062
K_Fpr = 0.012
K_KatE = 18.2 
H_2O = 1
ATP = 1
CoA = 1
CAR_apo = 1

# A = Acetoacetyl-CoA
# B = Acetyl-CoA
# C = NADPH
# D = 3-hydroxybutyryl-CoA
# E = Crotonyl-CoA
# F = Butyryl-CoA
# G = Butyric-acid
# H = Butyraldehyde
# I = H_+
# J = O_2
# K = NADH
# L = K_CARholo
# M = H2O2


# Define system in terms of separated differential equations
def r1(A,B,C):
    return K_AtoB*A - K_Hbd*B*C

def r2(A,C,D):
    return K_Hbd*A*C - K_Crt*D*H_2O

def r3(C,D,E):
    return  K_Crt*D*H_2O - K_Ter*E*C

def r4(E,C,F):
    return K_Ter*E*C - K_YciA*F*H_2O

def r5(F,G,C):
    return K_YciA*F*H_2O - K_CAR*G*C*H_2O*ATP

def r6(G,C,H,I,J):
    return K_CAR*G*C*H_2O*ATP - K_ADO*H*C**2*I**2*J**2

def r7(H,C,I,J):
    return K_ADO*H*C**2*I**2*J**2

def r8(C, G):
    return K_Sfp*CAR_apo*CoA-K_CAR*G*C*H_2O*ATP

def r9(C, H, I, J):
    return K_Fpr*C-K_ADO*H*C**2*I**2*J**2

def r10(C, M):
    return K_Fpr*C-K_KatE*M


# initialize lists containing values
a = []
b = []
c = []
d = []
e = []
f = []
g = []
k = []
l = []
h = []

# Time Constant
T = 14000
# Timestep Constant
dT = 0.02

#iv1, iv2 = initial values, dt = timestep, time = range
def sys(iv1, iv2, iv3, iv4, iv5, iv6, iv7, iv8, iv9, iv10, dt, time):
    # initial values:
    a.append(iv1)
    b.append(iv2)
    c.append(iv3)
    d.append(iv4)
    e.append(iv5)
    f.append(iv6)
    g.append(iv7)
    k.append(iv8)
    l.append(iv9)
    h.append(iv10)
    #z.append(iv3)
    # compute and fill lists
    for i in range(time):
        a.append(a[i] + (r1(1,a[i],1)) * dt)
        b.append(b[i] + (r2(a[i],1,b[i])) * dt)
        c.append(c[i] + (r3(1,b[i],c[i])) * dt)
        d.append(d[i] + (r4(c[i],1,d[i])) * dt)
        e.append(e[i] + (r5(d[i],e[i],1)) * dt)
        f.append(f[i] + (r6(e[i],1,f[i],1,1)) * dt)
        g.append(g[i] + (r7(f[i],1,1,1)) * dt)
        k.append(k[i] + (r8(1,e[i])) * dt)
        l.append(l[i] + (r9(1,f[i],1,1)) * dt)
        h.append(h[i] + (r10(1,h[i])) * dt)
        #z.append(z[i] + (h(x[i],y[i],z[i])) * dt)
    return a, b, c, d, e, f, g, j, k, l, h


#Dumping some values for NADPH & NADH
sys(100, 0, 0, 0, 0, 0, 0, 0, 0, 0,  dT, T)

#plot
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax1 = fig.add_subplot(1,2,1)
#ax2 = fig.add_subplot(1,2,2)

ax1.plot(a, 'k-', label='Acetoacetyl-CoA')
ax1.plot(b, 'b-', label='3-hydroxybutyryl-CoA')
ax1.plot(c, 'g-', label='Crotonyl-CoA')
ax1.plot(d, 'c-', label='Butyryl-CoA')
ax1.plot(e, 'm-', label='Butyric-acid')
ax1.plot(f, 'y-', label='Butyraldehyde')
ax1.plot(g, 'r-', label='Propane')
#ax1.plot(k, 'k-', label='CAR-holo')
#ax1.plot(l, 'k-', label='PetF-red')
ax1.plot(h, 'k-', label='H2O2')

ax1.set_title("Dynamics in time")
ax1.set_xlabel("time")
ax1.set_ylabel("Concentrations")
ax1.grid()
ax1.legend(loc='best')

#ax2.plot(x, y, color="blue")
#ax2.set_xlabel("x")
#ax2.set_ylabel("y")  
#ax2.set_title("Phase space")
#ax2.grid()

# %%
# Calculating the derivatives of the concentrations according to time

# Derivatives
a_D = []
b_D = []
c_D = []
d_D = []
e_D = []
f_D = []
g_D = []
k_D = []
l_D = []
h_D = []

# Calculate derivatives using timestep dT, through time T
for i in range(T-1):
    a_D.append(-(a[i+1]-a[i])/dT)
    b_D.append(-(b[i+1]-b[i])/dT) 
    c_D.append(-(c[i+1]-c[i])/dT)
    d_D.append(-(d[i+1]-d[i])/dT)
    e_D.append(-(e[i+1]-e[i])/dT)
    f_D.append(-(f[i+1]-f[i])/dT)
    g_D.append(-(g[i+1]-g[i])/dT)
    k_D.append(-(k[i+1]-k[i])/dT)
    l_D.append(-(l[i+1]-l[i])/dT)
    h_D.append(-(h[i+1]-h[i])/dT)

#plot
fig = plt.figure(figsize=(30,8))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax2 = fig.add_subplot(1,2,1)

ax2.plot(a_D, 'r-', label='Acetoacetyl-CoA')
ax2.plot(b_D, 'b-', label='3-hydroxybutyryl-CoA')
ax2.plot(c_D, 'g-', label='Crotonyl-CoA')
ax2.plot(d_D, 'c-', label='Butyryl-CoA')
ax2.plot(e_D, 'm-', label='Butyric-acid')
ax2.plot(f_D, 'y-', label='Butyraldehyde')
ax2.plot(g_D, 'k-', label='Propane')
ax2.plot(k_D, 'b-', label='CAR-holo')
ax2.plot(l_D, 'g-', label='PetF-red')
ax2.plot(h_D, 'g-', label='H2O2')

ax2.set_title("Negative derivatives of concentrations in time")
ax2.set_xlabel("time")
ax2.set_ylabel("Negative Derivative of Concentration")
ax2.grid()
ax2.legend()
